# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskarMonish/Iris-Flower-Classification/blob/main/Iris_Flowers_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
headernames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
figure(figsize=(10, 8), dpi=80)

plt.style.use('ggplot')
plt.xlabel('age and bmi')
plt.ylabel('charges')
plt.scatter(x=df['SepalLengthCm'],y=df['Species'],c='b',s=100,alpha=0.6,marker='o',edgecolors='y')
plt.scatter(x=df['PetalLengthCm'],y=df['Species'],c='r',s=100,alpha=0.5,marker='h',edgecolors='b')
plt.scatter(x=df['PetalWidthCm'],y=df['Species'],s=100,c='k',alpha=0.5,marker='h',edgecolors='b')
plt.scatter(x=df['SepalWidthCm'],y=df['Species'],c='g',s=100,alpha=0.5,marker='h',edgecolors='b')
plt.tight_layout()
plt.show()

# %%
X = df.iloc[:, 1:-1].values
y = df.iloc[:, 5].values

# %%
print(df.shape)
print(X.shape)
print(y.shape)
# Out:
# (150, 6)
# (150, 4)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifier = KNeighborsClassifier(n_neighbors = 3)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = classifier.predict(X_test)

# %%
new_data=[[6.1,3.5,5.5,2.2]]
prediction = classifier.predict(new_data)
prediction[0]
# Out:
# 'Iris-virginica'

# %%
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2)
# Out:
# Confusion Matrix:
# [[20  0  0]
#  [ 0 18  2]
#  [ 0  2 18]]
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        20
# Iris-versicolor       0.90      0.90      0.90        20
#  Iris-virginica       0.90      0.90      0.90        20
#
#        accuracy                           0.93        60
#       macro avg       0.93      0.93      0.93        60
#    weighted avg       0.93      0.93      0.93        60
#
# Accuracy: 0.9333333333333333

# %%
df = pd.read_csv("/content/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...
